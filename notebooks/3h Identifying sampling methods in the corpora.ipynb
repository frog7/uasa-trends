# %% [markdown]
# Initial setup

# %%
# %run "Common setup.ipynb"
# Out:
# C:\Users\douglasd\AppData\Local\Continuum\miniconda3\envs\biblio\lib\site-packages\fuzzywuzzy-0.17.0-py3.6.egg\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
RC = mk.RecordCollection("{}/rest_filtered_corpora.txt".format(TMP_DIR))
corpora_df = wosis.rc_to_df(RC)

# %%
corpora_df.to_csv('{}/corpora_rest.csv'.format(DATA_DIR))

# %% [markdown]
# Searching for sampling methods and plotting the keyword and publication trend of the results

# %%
topics = ['monte carlo', 'mc sampling', 'latin hypercube', 'lhs', 'morris screening', 'morris method']
sampling = wosis.keyword_matches(RC, ['monte carlo', 'mc sampling', 'latin hypercube', 'lhs', 'morris screening', 
                                      'morris method'], threshold=95.0)

# %%
all_samp = sampling.combine_recs()

# %%
wos_plot.plot_kw_trend(all_samp, title='Sampling Keyword Trend', save_plot_fn='{}/sampling_kw_trend.png'.format(FIG_DIR))

# %%
wos_plot.plot_pub_trend(all_samp, title='Sampling Publication Trend', save_plot_fn='{}/samp_pub_trend.png'.format(FIG_DIR))

# %% [markdown]
# <hr> Topic trend

# %%
all_samp.name = 'Sampling Methods'

# %%
wos_plot.plot_topic_trend([all_samp], save_plot_fn='{}/samp_topic_trend.png'.format(FIG_DIR))

# %%
wos_plot.plot_topic_trend([all_samp], total_rc=RC, title='Topic Trend as a Percentage of the Corpora', 
                          save_plot_fn='{}/samp_topic_trend_percentage.png'.format(FIG_DIR))
