# %% [markdown]
# Initial setup

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import wosis
import pandas as pd
import metaknowledge as mk

# Helper functions for plotting
import wosis.analysis.plotting as wos_plot

# Analysis and search functions
from wosis.analysis import (preview_matches, search_records, keyword_matches, 
                            find_pubs_by_authors, preview_matches_by_keyword, get_unique_kw_titles,
                            remove_by_journals, remove_by_title)

# Plotting libraries
import matplotlib.pyplot as plt
import seaborn as sns

# This just helps make the plots look nicer
sns.set_style('darkgrid')
sns.set_context('paper', font_scale=2.0)
# Out:
# C:\Users\douglasd\AppData\Local\Continuum\miniconda3\envs\biblio\lib\site-packages\fuzzywuzzy-0.17.0-py3.6.egg\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
RC = mk.RecordCollection("tmp/rest_requested_corpora.txt")
corpora_df = wosis.rc_to_df(RC)

# %%
wos_config = wosis.load_config('config.yml')

# %% [markdown]
# Searching for sampling methods, plotting keyword and publication trend

# %%
sampling = wosis.keyword_matches(RC, ['monte carlo', 'mc sampling', 'latin hypercube', 'lhs', 'morris screening', 'morris method'], threshold=95.0)

# %%
all_samp = sampling.combine_recs()

# %%
wos_plot.plot_kw_trend(all_samp, title='Sampling Keyword Trend', save_plot_fn='figs/sampling_kw_trend.png')

# %%
wos_plot.plot_pub_trend(all_samp, title='Sampling Publication Trend', save_plot_fn='figs/samp_pub_trend.png')

# %% [markdown]
# <hr> Topic trend

# %%
wos_plot.plot_topic_trend([all_samp], save_plot_fn='figs/samp_topic_trend.png')

# %%
wos_plot.plot_topic_trend([all_samp], total_rc=RC, title='Topic Trend as a Percentage of the Corpora', save_plot_fn='figs/samp_topic_trend_percentage.png')
