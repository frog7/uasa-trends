# %% [markdown]
# Use this to find papers of interest, in order to verify the scope of the search terms.  Investigated whoeol corpora and software packages keyword results.
# <hr>
# Initial setup

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import wosis
import pandas as pd
import metaknowledge as mk

# Helper functions for plotting
import wosis.analysis.plotting as wos_plot

# Analysis and search functions
from wosis.analysis import (preview_matches, search_records, keyword_matches, 
                            find_pubs_by_authors, preview_matches_by_keyword, get_unique_kw_titles,
                            remove_by_journals, remove_by_title)

# Plotting libraries
import matplotlib.pyplot as plt
import seaborn as sns

# This just helps make the plots look nicer
sns.set_style('darkgrid')
sns.set_context('paper', font_scale=2.0)
# Out:
# C:\Users\douglasd\AppData\Local\Continuum\miniconda3\envs\biblio\lib\site-packages\fuzzywuzzy-0.17.0-py3.6.egg\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
RC = mk.RecordCollection("tmp/rest_requested_corpora.txt")
corpora_df = wosis.rc_to_df(RC)

# %%
wos_config = wosis.load_config('config.yml')

# %%
software_packages = wosis.keyword_matches(RC, ['software', 'toolkit', 'toolbox'], threshold=95.0)

# %%
software_rc = software_packages.combine_recs()
software_df = wosis.rc_to_df(software_rc)

# %% [markdown]
# <hr>
# Finding papers of interest by DOI

# %%
#DAKOTA
corpora_df.loc[corpora_df['DOI'] == '10.2172/991842', :]
# Out:
# Empty DataFrame
# Columns: [id, year, title, keywords, abstract, copyright, AU, SO, DE, DOI]
# Index: []

# %%
#PSUADE
corpora_df.loc[corpora_df['DOI'] == '10.1016/j.envsoft.2013.09.031', :]
# Out:
#                        id  year  \
# 3322  WOS:000329561100024  2014
#
#                                                   title  \
# 3322  A comprehensive evaluation of various sensitiv...
#
#                                                keywords  \
# 3322  RAINFALL-RUNOFF MODELS|IMPROVED CALIBRATION|CO...
#
#                                                abstract  \
# 3322  sensitivity analysis sa is a commonly used app...
#
#                                                      AU  \
# 3322  Gan, Yanjun|Duan, Qingyun|Gong, Wei|Tong, Char...
#
#                                       SO  \
# 3322  ENVIRONMENTAL MODELLING & SOFTWARE
#
#                                                      DE  \
# 3322  uncertainty quantification|sensitivity analysi...
#
#                                 DOI
# 3322  10.1016/j.envsoft.2013.09.031

# %%
software_df.loc[software_df['DOI'] == '10.1016/j.envsoft.2013.09.031', :]
# Out:
#                      id  year  \
# 27  WOS:000329561100024  2014
#
#                                                 title  \
# 27  A comprehensive evaluation of various sensitiv...
#
#                                              keywords  \
# 27  RAINFALL-RUNOFF MODELS IMPROVED CALIBRATION CO...
#
#                                              abstract  \
# 27  Sensitivity analysis (SA) is a commonly used a...
#
#                               copyright  \
# 27   Elsevier Ltd. All rights reserved.
#
#                                                    AU  \
# 27  Gan, YJ|Duan, QY|Gong, W|Tong, C|Sun, YW|Chu, ...
#
#                                     SO  \
# 27  ENVIRONMENTAL MODELLING & SOFTWARE
#
#                                                    DE  \
# 27  uncertainty quantification sensitivity analysi...
#
#                               DOI
# 27  10.1016/j.envsoft.2013.09.031

# %%
#SALib: too recent?
corpora_df.loc[corpora_df['DOI'] == '10.21105/joss.00097', :]
# Out:
# Empty DataFrame
# Columns: [id, year, title, keywords, abstract, AU, SO, DE, DOI]
# Index: []

# %%
#UQLab
corpora_df.loc[corpora_df['DOI'] == '10.1061/9780784413609.257', :]
# Out:
# Empty DataFrame
# Columns: [id, year, title, keywords, abstract, AU, SO, DE, DOI]
# Index: []

# %%
#SAFE
corpora_df.loc[corpora_df['DOI'] == '10.1016/j.envsoft.2015.04.009', :]
# Out:
#                         id  year  \
# 12346  WOS:000356741300007  2015
#
#                                                   title  \
# 12346  A Matlab toolbox for Global Sensitivity Analysis
#
#                                   keywords  \
# 12346  IDENTIFICATION|UNCERTAINTIES|MODELS
#
#                                                 abstract  \
# 12346  global sensitivity analysis gsa is increasingl...
#
#                                                       AU  \
# 12346  Pianosi, Francesca|Sarrazin, Fanny|Wagener, Th...
#
#                                        SO  \
# 12346  ENVIRONMENTAL MODELLING & SOFTWARE
#
#                                                       DE  \
# 12346  global sensitivity analysis|matlab|octave|open...
#
#                                  DOI
# 12346  10.1016/j.envsoft.2015.04.009

# %%
software_df.loc[software_df['DOI'] == '10.1016/j.envsoft.2015.04.009', :]
# Out:
#                      id  year  \
# 83  WOS:000356741300007  2015
#
#                                                title  \
# 83  A Matlab toolbox for Global Sensitivity Analysis
#
#                                keywords  \
# 83  IDENTIFICATION UNCERTAINTIES MODELS
#
#                                              abstract  \
# 83  Global Sensitivity Analysis (GSA) is increasin...
#
#                       copyright                                 AU  \
# 83   Published by Elsevier Ltd.  Pianosi, F|Sarrazin, F|Wagener, T
#
#                                     SO  \
# 83  ENVIRONMENTAL MODELLING & SOFTWARE
#
#                                                    DE  \
# 83  global sensitivity analysis matlab octave open...
#
#                               DOI
# 83  10.1016/j.envsoft.2015.04.009

# %%
#VARS-TOOL: too recent, using preceeding (2016) paper
corpora_df.loc[corpora_df['DOI'] == '10.1002/2015WR017559', :]
# Out:
#                       id  year  \
# 189  WOS:000373117800026  2016
#
#                                                  title keywords  \
# 189  A new framework for comprehensive, robust, and...   MODELS
#
#                                               abstract  \
# 189  based on the theoretical framework for sensiti...
#
#                                  AU                        SO DE  \
# 189  Razavi, Saman|Gupta, Hoshin V.  WATER RESOURCES RESEARCH
#
#                       DOI
# 189  10.1002/2015WR017559

# %%
software_df.loc[software_df['DOI'] == '10.1002/2015WR017559', :]
# Out:
# Empty DataFrame
# Columns: [id, year, title, keywords, abstract, copyright, AU, SO, DE, DOI]
# Index: []

# %%
#VARS-TOOL: too recent, using preceeding (2016) paper
corpora_df.loc[corpora_df['DOI'] == '10.1002/2015WR017558', :]
# Out:
#                        id  year  \
# 5206  WOS:000373117800025  2016
#
#                                                   title keywords  \
# 5206  A new framework for comprehensive, robust, and...   MODELS
#
#                                                abstract  \
# 5206  computer simulation models are continually gro...
#
#                                   AU                        SO DE  \
# 5206  Razavi, Saman|Gupta, Hoshin V.  WATER RESOURCES RESEARCH
#
#                        DOI
# 5206  10.1002/2015WR017558

# %%
software_df.loc[software_df['DOI'] == '10.1002/2015WR017558', :]
# Out:
# Empty DataFrame
# Columns: [id, year, title, keywords, abstract, copyright, AU, SO, DE, DOI]
# Index: []

# %%
#GUI-HDMR
corpora_df.loc[corpora_df['DOI'] == '10.1016/j.envsoft.2008.12.002', :]
# Out:
#                        id  year  \
# 5937  WOS:000265341800001  2009
#
#                                                   title  \
# 5937  GUI-HDMR - A software tool for global sensitiv...
#
#                                                keywords  \
# 5937  STREET CANYON MODEL ENVIRONMENTAL-MODELS RS-HD...
#
#                                                abstract  \
# 5937  The high dimensional model representation (HDM...
#
#                                 copyright                   AU  \
# 5937   Elsevier Ltd. All rights reserved.  Ziehn, T|Tomlin, AS
#
#                                       SO  \
# 5937  ENVIRONMENTAL MODELLING & SOFTWARE
#
#                                                      DE  \
# 5937  global sensitivity analysis high dimensional m...
#
#                                 DOI
# 5937  10.1016/j.envsoft.2008.12.002

# %%
software_df.loc[software_df['DOI'] == '10.1016/j.envsoft.2008.12.002', :]
# Out:
#                      id  year  \
# 55  WOS:000265341800001  2009
#
#                                                 title  \
# 55  GUI-HDMR - A software tool for global sensitiv...
#
#                                              keywords  \
# 55  STREET CANYON MODEL ENVIRONMENTAL-MODELS RS-HD...
#
#                                              abstract  \
# 55  The high dimensional model representation (HDM...
#
#                               copyright                   AU  \
# 55   Elsevier Ltd. All rights reserved.  Ziehn, T|Tomlin, AS
#
#                                     SO  \
# 55  ENVIRONMENTAL MODELLING & SOFTWARE
#
#                                                    DE  \
# 55  global sensitivity analysis high dimensional m...
#
#                               DOI
# 55  10.1016/j.envsoft.2008.12.002

# %%
#searching for Jefferson active subspaces paper
corpora_df.loc[corpora_df['DOI'] == '10.1016/j.cageo.2015.07.001', :]
# Out:
#                         id  year  \
# 12426  WOS:000361400900014  2015
#
#                                                    title  \
# 12426  Active subspaces for sensitivity analysis and ...
#
#                                                 keywords  \
# 12426  COMMON LAND MODEL|SURFACE PARAMETERS|ENERGY FL...
#
#                                                 abstract  \
# 12426  integrated hydrologic models coupled to land s...
#
#                                                       AU  \
# 12426  Jefferson, Jennifer L.|Gilbert, James M.|Const...
#
#                             SO  \
# 12426  COMPUTERS & GEOSCIENCES
#
#                                                       DE  \
# 12426  active subspaces|dimension reduction|energy fl...
#
#                                DOI
# 12426  10.1016/j.cageo.2015.07.001

# %%
software_df.loc[software_df['DOI'] == '10.1016/j.cageo.2015.07.001', :]
# Out:
# Empty DataFrame
# Columns: [id, year, title, keywords, abstract, copyright, AU, SO, DE, DOI]
# Index: []

# %% [markdown]
# <hr>
# Finding papers which mention papers/packages of interest in keywords

# %%
#SimLab
simlab_rc = wosis.search_records(RC, ["simlab"], threshold=95.0)
simlab_df = wosis.rc_to_df(simlab_rc)

simlab_df.head()
# Out:
#                     id  year  \
# 0  WOS:000238960100008  2006
# 1  WOS:000279410600016  2010
# 2  WOS:000408861800155  2017
#
#                                                title  \
# 0  Variance-based sensitivity analysis of the pro...
# 1  Sensitivity analysis in fuzzy systems: Integra...
# 2  Improving Thermal Comfort of Low-Income Housin...
#
#                                             keywords  \
# 0  STABILITY MODEL UNSATURATED SOILS UNCERTAINTY ...
# 1  REAL-TIME PCR SOLAR-RADIATION MODEL QUANTIFICA...
# 2  TROPICAL HUMID REGION BUILDINGS STANDARDS ADAP...
#
#                                             abstract  \
# 0  Analysis of the sensitivity of predictions of ...
# 1  This work addresses the sensitivity analysis o...
# 2  In Thailand, the delivery of adequate low-inco...
#
#                              copyright  \
# 0   Elsevier Ltd. All rights reserved.
# 1   Elsevier Ltd. All rights reserved.
# 2
#
#                                                   AU  \
# 0                    Hamm, NAS|Hall, JW|Anderson, MG
# 1  Foscarini, F|Bellocchi, G|Confalonieri, R|Savi...
# 2               Bhikhoo, N|Hashemi, A|Cruickshank, H
#
#                                    SO  \
# 0             COMPUTERS & GEOSCIENCES
# 1  ENVIRONMENTAL MODELLING & SOFTWARE
# 2                      SUSTAINABILITY
#
#                                                   DE  \
# 0  site investigation slope stability analysis st...
# 1  dana-flsa fuzzy logic genetically modified org...
# 2  thermal comfort low income housing thailand tr...
#
#                              DOI
# 0    10.1016/j.cageo.2005.10.007
# 1  10.1016/j.envsoft.2010.03.024
# 2              10.3390/su9081440

# %%
simlab_rc = wosis.search_records(software_rc, ["simlab"], threshold=95.0)
simlab_df = wosis.rc_to_df(simlab_rc)

simlab_df.head()
# Out:
#                     id  year  \
# 0  WOS:000238960100008  2006
# 1  WOS:000408861800155  2017
#
#                                                title  \
# 0  Variance-based sensitivity analysis of the pro...
# 1  Improving Thermal Comfort of Low-Income Housin...
#
#                                             keywords  \
# 0  STABILITY MODEL UNSATURATED SOILS UNCERTAINTY ...
# 1  TROPICAL HUMID REGION BUILDINGS STANDARDS ADAP...
#
#                                             abstract  \
# 0  Analysis of the sensitivity of predictions of ...
# 1  In Thailand, the delivery of adequate low-inco...
#
#                              copyright                                    AU  \
# 0   Elsevier Ltd. All rights reserved.       Hamm, NAS|Hall, JW|Anderson, MG
# 1                                       Bhikhoo, N|Hashemi, A|Cruickshank, H
#
#                         SO                                                 DE  \
# 0  COMPUTERS & GEOSCIENCES  site investigation slope stability analysis st...
# 1           SUSTAINABILITY  thermal comfort low income housing thailand tr...
#
#                            DOI
# 0  10.1016/j.cageo.2005.10.007
# 1            10.3390/su9081440

# %%
#DAKOTA
DAKOTA_rc = wosis.search_records(RC, ["DAKOTA"], threshold=95.0)
DAKOTA_df = wosis.rc_to_df(DAKOTA_rc)

DAKOTA_df.head()
# Out:
#                     id  year  \
# 0  WOS:000258519700024  2008
# 1  WOS:000418736000022  2017
# 2  WOS:000286782400011  2011
# 3  WOS:000170209200019  2001
# 4  WOS:000377473400008  2016
#
#                                                title  \
# 0  Bayesian dynamic modelling for nonstationary h...
# 1  A Lagging Model for Describing Drawdown Induce...
# 2    Devils lake emergency outlet diversion conflict
# 3  Net primary production of US Midwest croplands...
# 4  Cost comparison of syngas production from natu...
#
#                                             keywords  \
# 0  NORTH-ATLANTIC OSCILLATION ATMOSPHERIC CIRCULA...
# 1  SENSITIVITY-ANALYSIS WELLBORE STORAGE LA CHALE...
# 2  DECISION-SUPPORT-SYSTEM FRESH-WATER RESOURCES ...
# 3  IRRIGATED WINTER-WHEAT GENETIC-IMPROVEMENT AGR...
# 4                                                GTL
#
#                                             abstract  \
# 0  Forecasting of hydrologic time series, with th...
# 1  This study proposes a generalized Darcy's law ...
# 2  The Devils Lake Emergency Outlet Diversion con...
# 3  We studied crop harvested yield, as recorded i...
# 4  Underground coal gasification (UCG) is a promi...
#
#                                      copyright  \
# 0   Copyright (C) 2008 John Wiley & Sons, Ltd.
# 1
# 2           Elsevier Ltd. All rights reserved.
# 3
# 4
#
#                                                   AU  \
# 0                                 Kumar, DN|Maity, R
# 1                                    Lin, YC|Yeh, HD
# 2                             Ma, J|Hipel, KW|De, ML
# 3  Prince, SD|Haskett, J|Steininger, M|Strand, H|...
# 4                 Pei, P|Korom, SF|Ling, KG|Nasah, J
#
#                                                   SO  \
# 0                             HYDROLOGICAL PROCESSES
# 1                           WATER RESOURCES RESEARCH
# 2                JOURNAL OF ENVIRONMENTAL MANAGEMENT
# 3                            ECOLOGICAL APPLICATIONS
# 4  MITIGATION AND ADAPTATION STRATEGIES FOR GLOBA...
#
#                                                   DE  \
# 0  bayesian dynamic models nonstationarity foreca...
# 1
# 2  graph model for conflict resolution transbound...
# 3  agricultural statistics crop harvested yield h...
# 4  syngas underground coal gasification cost comp...
#
#                                                DOI
# 0                                 10.1002/hyp.6951
# 1                             10.1002/2017WR021115
# 2                    10.1016/j.jenvman.2010.08.027
# 3  10.1890/1051-0761(2001)011[1194:NPPOUS]2.0.CO;2
# 4                        10.1007/s11027-014-9588-x

# %%
DAKOTA_rc = wosis.search_records(software_rc, ["DAKOTA"], threshold=95.0)
DAKOTA_df = wosis.rc_to_df(DAKOTA_rc)

DAKOTA_df.head()
# Out:
#                     id  year  \
# 0  WOS:000374807600014  2016
#
#                                                title      keywords  \
# 0  Towards uncertainty quantification and paramet...  EQUIFINALITY
#
#                                             abstract  \
# 0  Component-based modeling frameworks make it ea...
#
#                              copyright  \
# 0   Elsevier Ltd. All rights reserved.
#
#                                             AU                       SO  \
# 0  Peckham, SD|Kelbert, A|Hill, MC|Hutton, EWH  COMPUTERS & GEOSCIENCES
#
#                                                   DE  \
# 0  model uncertainty modeling frameworks componen...
#
#                            DOI
# 0  10.1016/j.cageo.2016.03.005

# %%
#Sandia
sandia_rc = wosis.search_records(RC, ["sandia"], threshold=95.0)
sandia_df = wosis.rc_to_df(sandia_rc)

sandia_df.head()
# Out:
#                     id  year  \
# 0  WOS:000256856000013  2008
# 1  WOS:000243852300003  2007
# 2  WOS:000301715700008  2012
# 3  WOS:000343415200006  2013
# 4  WOS:000256856000015  2008
#
#                                                title  \
# 0            Formulation of the static frame problem
# 1  Control of downward migration of dense nonaque...
# 2  A reduced mechanism for biodiesel surrogates w...
# 3  UNCERTAINTY IN THE DEVELOPMENT AND USE OF EQUA...
# 4  A systematic approach to model validation base...
#
#                                             keywords  \
# 0
# 1  ENHANCED AQUIFER REMEDIATION HETEROGENEOUS AQU...
# 2  CHEMICAL KINETIC MECHANISMS PRINCIPAL COMPONEN...
# 3
# 4
#
#                                             abstract  \
# 0  This report describes a static framework valid...
# 1  [] Sand tank experiments have been used to stu...
# 2  Biodiesel is a promising alternative fuel for ...
# 3  In this paper we present the results from a se...
# 4  This work describes a solution to the validati...
#
#                                       copyright  \
# 0   (C) 2007 Elsevier B.V. All rights reserved.
# 1
# 2
# 3
# 4   (C) 2007 Elsevier B.V. All rights reserved.
#
#                                                   AU  \
# 0                    Babuska, I|Nobile, F|Tempone, R
# 1  Jin, MQ|Hirasaki, GJ|Jackson, RE|Kostarelos, K...
# 2        Luo, ZY|Plomer, M|Lu, TF|Som, S|Longman, DE
# 3  Weirs, VG|Fabian, N|Potter, K|McNamara, L|Otah...
# 4                    Babuska, I|Nobile, F|Tempone, R
#
#                                                   SO  \
# 0  COMPUTER METHODS IN APPLIED MECHANICS AND ENGI...
# 1                           WATER RESOURCES RESEARCH
# 2                    COMBUSTION THEORY AND MODELLING
# 3  INTERNATIONAL JOURNAL FOR UNCERTAINTY QUANTIFI...
# 4  COMPUTER METHODS IN APPLIED MECHANICS AND ENGI...
#
#                                                   DE  \
# 0  model validation uncertainty quantification fa...
# 1
# 2  mechanism reduction biodiesel auto-ignition lo...
# 3  materials uncertainty quantification represent...
# 4  model validation uncertainty quantification ba...
#
#                                                  DOI
# 0                          10.1016/j.cma.2007.12.010
# 1                               10.1029/2006WR004858
# 2                       10.1080/13647830.2011.631034
# 3  10.1615/Int.J.UncertaintyQuantification.201200...
# 4                          10.1016/j.cma.2007.08.031

# %%
sandia_rc = wosis.search_records(software_rc, ["sandia"], threshold=95.0)
sandia_df = wosis.rc_to_df(sandia_rc)

sandia_df.head()
# Out:
#                     id  year  \
# 0  WOS:000343415200006  2013
#
#                                                title keywords  \
# 0  UNCERTAINTY IN THE DEVELOPMENT AND USE OF EQUA...
#
#                                             abstract copyright  \
# 0  In this paper we present the results from a se...
#
#                                                   AU  \
# 0  Weirs, VG|Fabian, N|Potter, K|McNamara, L|Otah...
#
#                                                   SO  \
# 0  INTERNATIONAL JOURNAL FOR UNCERTAINTY QUANTIFI...
#
#                                                   DE  \
# 0  materials uncertainty quantification represent...
#
#                                                  DOI
# 0  10.1615/Int.J.UncertaintyQuantification.201200...

# %%
#UQLab
uqlab_rc = wosis.search_records(RC, ["uqlab"], threshold=95.0)
uqlab_df = wosis.rc_to_df(uqlab_rc)

uqlab_df.head()
# Out:
# Empty DataFrame
# Columns: [id, year, title, keywords, abstract, copyright, AU, SO, DE, DOI]
# Index: []

# %%
#SALib
salib_rc = wosis.search_records(RC, ["salib"], threshold=95.0)
salib_df = wosis.rc_to_df(salib_rc)

salib_df.head()
# Out:
# Empty DataFrame
# Columns: [id, year, title, keywords, abstract, copyright, AU, SO, DE, DOI]
# Index: []

# %%
#MADS
mads_rc = wosis.search_records(RC, ["mads", "julia"], threshold=95.0)
mads_df = wosis.rc_to_df(mads_rc)

mads_df.head()
# Out:
#                     id  year  \
# 0  WOS:000334856200002  2014
# 1  WOS:000404370900030  2017
# 2  WOS:000250330700010  2007
#
#                                                title  \
# 0  Analytical solutions for anomalous dispersion ...
# 1  High performance in power generation by pressu...
# 2  Using a Bayesian belief network to predict sui...
#
#                                             keywords  \
# 0  HIGHLY HETEROGENEOUS FORMATIONS NON-FICKIAN TR...
# 1  NATURAL SALINITY GRADIENTS HOLLOW-FIBER MEMBRA...
# 2  NORTHWEST FOREST PLAN WATERING-POINTS CONSERVA...
#
#                                             abstract  \
# 0  Groundwater flow and transport often occur in ...
# 1  Pressure-retarded osmosis (PRO) is a renewable...
# 2  Wildlife managers are often required to make i...
#
#                              copyright  \
# 0           Published by Elsevier Ltd.
# 1
# 2   Elsevier Ltd. All rights reserved.
#
#                                           AU  \
# 0                 O'Malley, D|Vesselinov, VV
# 1            Sharifan, H|Madsen, HT|Morse, A
# 2  Smith, CS|Howes, AL|Price, B|McAlpine, CA
#
#                                  SO  \
# 0       ADVANCES IN WATER RESOURCES
# 1  DESALINATION AND WATER TREATMENT
# 2           BIOLOGICAL CONSERVATION
#
#                                                   DE  \
# 0  anomalous dispersion stochastic transport anal...
# 1  urmia lake pressure-retarded osmosis renewable...
# 2  expert knowledge uncertainty wildlife manageme...
#
#                                DOI
# 0  10.1016/j.advwatres.2014.02.006
# 1           10.5004/dwt.2017.20555
# 2     10.1016/j.biocon.2007.06.025

# %%
mads_rc = wosis.search_records(software_rc, ["mads", "julia"], threshold=95.0)
mads_df = wosis.rc_to_df(mads_rc)

mads_df.head()
# Out:
# Empty DataFrame
# Columns: [id, year, title, keywords, abstract, copyright, AU, SO, DE, DOI]
# Index: []
