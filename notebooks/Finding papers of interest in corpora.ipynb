# %% [markdown]
# Initial setup

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import wosis
import pandas as pd
import metaknowledge as mk

# Helper functions for plotting
import wosis.analysis.plotting as wos_plot

# Analysis and search functions
from wosis.analysis import (preview_matches, search_records, keyword_matches, 
                            find_pubs_by_authors, preview_matches_by_keyword, get_unique_kw_titles,
                            remove_by_journals, remove_by_title)

# Plotting libraries
import matplotlib.pyplot as plt
import seaborn as sns

# This just helps make the plots look nicer
sns.set_style('darkgrid')
sns.set_context('paper', font_scale=2.0)
# Out:
# C:\Users\douglasd\AppData\Local\Continuum\miniconda3\envs\biblio\lib\site-packages\fuzzywuzzy-0.17.0-py3.6.egg\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
query_id = "756d39801152fe5f5f4ad3a3df9b6a30"
RC = mk.RecordCollection("tmp/{}.txt".format(query_id))

# Remove publications with no DOI
corpora_df = wosis.rc_to_df(RC)
corpora_df, removed_pubs = wosis.constrain.remove_empty_DOIs(corpora_df)

# Create a new metaknowledge collection
filtered_corpora = wosis.extract_recs(corpora_df.loc[:, 'id'], RC, name='Filtered Corpora')
# Out:
# Removing 1799 records with no DOIs

# %% [markdown]
# <hr>
# Finding papers of interest by DOI

# %%
#DAKOTA
corpora_df.loc[corpora_df['DOI'] == '10.2172/991842', :]
# Out:
# Empty DataFrame
# Columns: [id, year, title, keywords, abstract, AU, SO, DE, DOI]
# Index: []

# %%
#PSUADE
corpora_df.loc[corpora_df['DOI'] == '10.1016/j.envsoft.2013.09.031', :]
# Out:
#                        id  year  \
# 3322  WOS:000329561100024  2014
#
#                                                   title  \
# 3322  A comprehensive evaluation of various sensitiv...
#
#                                                keywords  \
# 3322  RAINFALL-RUNOFF MODELS|IMPROVED CALIBRATION|CO...
#
#                                                abstract  \
# 3322  sensitivity analysis sa is a commonly used app...
#
#                                                      AU  \
# 3322  Gan, Yanjun|Duan, Qingyun|Gong, Wei|Tong, Char...
#
#                                       SO  \
# 3322  ENVIRONMENTAL MODELLING & SOFTWARE
#
#                                                      DE  \
# 3322  uncertainty quantification|sensitivity analysi...
#
#                                 DOI
# 3322  10.1016/j.envsoft.2013.09.031

# %%
#SALib: too recent?
corpora_df.loc[corpora_df['DOI'] == '10.21105/joss.00097', :]
# Out:
# Empty DataFrame
# Columns: [id, year, title, keywords, abstract, AU, SO, DE, DOI]
# Index: []

# %%
#UQLab
corpora_df.loc[corpora_df['DOI'] == '10.1061/9780784413609.257', :]
# Out:
# Empty DataFrame
# Columns: [id, year, title, keywords, abstract, AU, SO, DE, DOI]
# Index: []

# %%
#SAFE
corpora_df.loc[corpora_df['DOI'] == '10.1016/j.envsoft.2015.04.009', :]
# Out:
#                         id  year  \
# 12346  WOS:000356741300007  2015
#
#                                                   title  \
# 12346  A Matlab toolbox for Global Sensitivity Analysis
#
#                                   keywords  \
# 12346  IDENTIFICATION|UNCERTAINTIES|MODELS
#
#                                                 abstract  \
# 12346  global sensitivity analysis gsa is increasingl...
#
#                                                       AU  \
# 12346  Pianosi, Francesca|Sarrazin, Fanny|Wagener, Th...
#
#                                        SO  \
# 12346  ENVIRONMENTAL MODELLING & SOFTWARE
#
#                                                       DE  \
# 12346  global sensitivity analysis|matlab|octave|open...
#
#                                  DOI
# 12346  10.1016/j.envsoft.2015.04.009

# %%
#VARS-TOOL: too recent, using preceeding (2016) paper
corpora_df.loc[corpora_df['DOI'] == '10.1002/2015WR017559', :]
# Out:
#                       id  year  \
# 189  WOS:000373117800026  2016
#
#                                                  title keywords  \
# 189  A new framework for comprehensive, robust, and...   MODELS
#
#                                               abstract  \
# 189  based on the theoretical framework for sensiti...
#
#                                  AU                        SO DE  \
# 189  Razavi, Saman|Gupta, Hoshin V.  WATER RESOURCES RESEARCH
#
#                       DOI
# 189  10.1002/2015WR017559

# %%
#VARS-TOOL: too recent, using preceeding (2016) paper
corpora_df.loc[corpora_df['DOI'] == '10.1002/2015WR017558', :]
# Out:
#                        id  year  \
# 5206  WOS:000373117800025  2016
#
#                                                   title keywords  \
# 5206  A new framework for comprehensive, robust, and...   MODELS
#
#                                                abstract  \
# 5206  computer simulation models are continually gro...
#
#                                   AU                        SO DE  \
# 5206  Razavi, Saman|Gupta, Hoshin V.  WATER RESOURCES RESEARCH
#
#                        DOI
# 5206  10.1002/2015WR017558

# %%
#GUI-HDMR
corpora_df.loc[corpora_df['DOI'] == '10.1016/j.envsoft.2008.12.002', :]
# Out:
#                        id  year  \
# 4206  WOS:000265341800001  2009
#
#                                                   title  \
# 4206  GUI-HDMR - A software tool for global sensitiv...
#
#                                                keywords  \
# 4206  STREET CANYON MODEL|ENVIRONMENTAL-MODELS|RS-HD...
#
#                                                abstract  \
# 4206  the high dimensional model representation hdmr...
#
#                            AU                                  SO  \
# 4206  Ziehn, T.|Tomlin, A. S.  ENVIRONMENTAL MODELLING & SOFTWARE
#
#                                                      DE  \
# 4206  global sensitivity analysis|high dimensional m...
#
#                                 DOI
# 4206  10.1016/j.envsoft.2008.12.002

# %%
#searching for Jefferson active subspaces paper
corpora_df.loc[corpora_df['DOI'] == '10.1016/j.cageo.2015.07.001', :]
# Out:
#                         id  year  \
# 12426  WOS:000361400900014  2015
#
#                                                    title  \
# 12426  Active subspaces for sensitivity analysis and ...
#
#                                                 keywords  \
# 12426  COMMON LAND MODEL|SURFACE PARAMETERS|ENERGY FL...
#
#                                                 abstract  \
# 12426  integrated hydrologic models coupled to land s...
#
#                                                       AU  \
# 12426  Jefferson, Jennifer L.|Gilbert, James M.|Const...
#
#                             SO  \
# 12426  COMPUTERS & GEOSCIENCES
#
#                                                       DE  \
# 12426  active subspaces|dimension reduction|energy fl...
#
#                                DOI
# 12426  10.1016/j.cageo.2015.07.001

# %% [markdown]
# <hr>
# Finding papers which mention papers/packages of interest in keywords

# %%
#SimLab
simlab_rc = wosis.search_records(filtered_corpora, ["simlab"], threshold=95.0)
simlab_df = wosis.rc_to_df(simlab_rc)

simlab_df.head()
# Out:
#                     id  year  \
# 0  WOS:000388157900001  2016
# 1  WOS:000279410600016  2010
# 2  WOS:000238960100008  2006
# 3  WOS:000408861800155  2017
# 4  WOS:000274350400010  2010
#
#                                                title  \
# 0  Implementing a composite indicator approach fo...
# 1  Sensitivity analysis in fuzzy systems: Integra...
# 2  Variance-based sensitivity analysis of the pro...
# 3  Improving Thermal Comfort of Low-Income Housin...
# 4  Sensitivity analysis of the rice model WARM in...
#
#                                             keywords  \
# 0  INDEX|SUSTAINABILITY|PERFORMANCE|MANAGEMENT|TU...
# 1  REAL-TIME PCR|SOLAR-RADIATION|MODEL|QUANTIFICA...
# 2  STABILITY MODEL|UNSATURATED SOILS|UNCERTAINTY|...
# 3  TROPICAL HUMID REGION|BUILDINGS|STANDARDS|ADAP...
# 4                  FLOODED RICE|YIELD|SIMULATE|WATER
#
#                                             abstract  \
# 0  successful implementation of the european urba...
# 1  this work addresses the sensitivity analysis o...
# 2  analysis of the sensitivity of predictions of ...
# 3  in thailand the delivery of adequate lowincome...
# 4  sensitivity analysis studies how the variation...
#
#                                                   AU  \
# 0   Sabia, Gianpaolo|De Gisi, Sabino|Farina, Roberto
# 1  Foscarini, F.|Bellocchi, G.|Confalonieri, R.|S...
# 2         Hamm, N. A. S.|Hall, J. W.|Anderson, M. G.
# 3  Bhikhoo, Nafisa|Hashemi, Arman|Cruickshank, He...
# 4  Confalonieri, Roberto|Bellocchi, Gianni|Tarant...
#
#                                    SO  \
# 0               ECOLOGICAL INDICATORS
# 1  ENVIRONMENTAL MODELLING & SOFTWARE
# 2             COMPUTERS & GEOSCIENCES
# 3                      SUSTAINABILITY
# 4  ENVIRONMENTAL MODELLING & SOFTWARE
#
#                                                   DE  \
# 0  composite indicator|municipal wwtps|prioritiza...
# 1  dana-flsa|fuzzy logic|genetically modified org...
# 2  site investigation|slope stability analysis|st...
# 3  thermal comfort|low income housing|thailand|tr...
# 4  aboveground biomass|morris method|simlab|simul...
#
#                              DOI
# 0  10.1016/j.ecolind.2016.06.053
# 1  10.1016/j.envsoft.2010.03.024
# 2    10.1016/j.cageo.2005.10.007
# 3              10.3390/su9081440
# 4  10.1016/j.envsoft.2009.10.005

# %%
#DAKOTA
DAKOTA_rc = wosis.search_records(filtered_corpora, ["DAKOTA"], threshold=95.0)
DAKOTA_df = wosis.rc_to_df(DAKOTA_rc)

DAKOTA_df.head()
# Out:
#                     id  year  \
# 0  WOS:000207576300010  2008
# 1  WOS:000220980100002  2004
# 2  WOS:000377473400008  2016
# 3  WOS:000374807600014  2016
# 4  WOS:000258519700024  2008
#
#                                                title  \
# 0  Switchgrass Biomass Simulation at Diverse Site...
# 1  Uncertainty of predictions of embankment dam b...
# 2  Cost comparison of syngas production from natu...
# 3  Towards uncertainty quantification and paramet...
# 4  Bayesian dynamic modelling for nonstationary h...
#
#                                             keywords  \
# 0
# 1                                            OUTFLOW
# 2                                                GTL
# 3                                       EQUIFINALITY
# 4  NORTH-ATLANTIC OSCILLATION|ATMOSPHERIC CIRCULA...
#
#                                             abstract  \
# 0  the agricultural land management alternatives ...
# 1  risk assessment studies considering the failur...
# 2  underground coal gasification ucg is a promisi...
# 3  componentbased modeling frameworks make it eas...
# 4  forecasting of hydrologic time series with the...
#
#                                                   AU  \
# 0  Kiniry, J. R.|Schmer, M. R.|Vogel, K. P.|Mitch...
# 1                                           Wahl, TL
# 2  Pei, Peng|Korom, Scott F.|Ling, Kegang|Nasah, ...
# 3  Peckham, Scott D.|Kelbert, Anna|Hill, Mary C.|...
# 4                      Kumar, D. Nagesh|Maity, Rajib
#
#                                                   SO  \
# 0                                 BIOENERGY RESEARCH
# 1              JOURNAL OF HYDRAULIC ENGINEERING-ASCE
# 2  MITIGATION AND ADAPTATION STRATEGIES FOR GLOBA...
# 3                            COMPUTERS & GEOSCIENCES
# 4                             HYDROLOGICAL PROCESSES
#
#                                                   DE  \
# 0                biofuel|degree days|leaf area index
# 1  dam failure|uncertainty analysis|peak flow|ero...
# 2  syngas|underground coal gasification|cost comp...
# 3  model uncertainty|modeling frameworks|componen...
# 4  bayesian dynamic models|nonstationarity|foreca...
#
#                                        DOI
# 0                10.1007/s12155-008-9024-8
# 1  10.1061/(ASCE)0733-9429(2004)130:5(389)
# 2                10.1007/s11027-014-9588-x
# 3              10.1016/j.cageo.2016.03.005
# 4                         10.1002/hyp.6951

# %%
#Sandia
sandia_rc = wosis.search_records(filtered_corpora, ["sandia"], threshold=95.0)
sandia_df = wosis.rc_to_df(Sandia_rc)

sandia_df.head()
# Out:
#                     id  year  \
# 0  WOS:000256856000010  2008
# 1  WOS:000257094800005  2008
# 2  WOS:000343415200006  2013
# 3  WOS:000256856000013  2008
# 4  WOS:000243852300003  2007
#
#                                                title  \
# 0  Multivariate significance testing and model ca...
# 1  Analytical risk-based model of gaseous and liq...
# 2  UNCERTAINTY IN THE DEVELOPMENT AND USE OF EQUA...
# 3            Formulation of the static frame problem
# 4  Control of downward migration of dense nonaque...
#
#                                             keywords  \
# 0  COMPUTATIONAL MODELS|COMPUTER-MODELS|VALIDATIO...
# 1                SENSITIVITY-ANALYSIS|SOIL|DIFFUSION
# 2
# 3
# 4  ENHANCED AQUIFER REMEDIATION|HETEROGENEOUS AQU...
#
#                                             abstract  \
# 0  the importance of modeling and simulation in t...
# 1  an analytical model of gaseous and liquidphase...
# 2  in this paper we present the results from a se...
# 3  this report describes a static framework valid...
# 4   sand tank experiments have been used to study...
#
#                                                   AU  \
# 0                McFarland, John|Mahadevan, Sankaran
# 1                                    Ho, Clifford K.
# 2  Weirs, V. Gregory|Fabian, Nathan|Potter, Krist...
# 3                 Babuska, I.|Nobile, F.|Tempone, R.
# 4  Jin, Minquan|Hirasaki, George J.|Jackson, Rich...
#
#                                                   SO  \
# 0  COMPUTER METHODS IN APPLIED MECHANICS AND ENGI...
# 1                 ENVIRONMENTAL MODELLING & SOFTWARE
# 2  INTERNATIONAL JOURNAL FOR UNCERTAINTY QUANTIFI...
# 3  COMPUTER METHODS IN APPLIED MECHANICS AND ENGI...
# 4                           WATER RESOURCES RESEARCH
#
#                                                   DE  \
# 0  model validation|multivariate statistics|signi...
# 1  radon|landfill|multiphase|transport|radium|pro...
# 2  materials|uncertainty quantification|represent...
# 3  model validation|uncertainty quantification|fa...
# 4
#
#                                                  DOI
# 0                          10.1016/j.cma.2007.05.030
# 1                      10.1016/j.envsoft.2008.01.002
# 2  10.1615/Int.J.UncertaintyQuantification.201200...
# 3                          10.1016/j.cma.2007.12.010
# 4                               10.1029/2006WR004858

# %%
sandia_df.to_csv('sandia_papers.csv', index=False)

# %%
#UQLab
uqlab_rc = wosis.search_records(filtered_corpora, ["uqlab"], threshold=95.0)
uqlab_df = wosis.rc_to_df(uqlab_rc)

uqlab_df.head()
# Out:
# Empty DataFrame
# Columns: [id, year, title, keywords, abstract, AU, SO, DE, DOI]
# Index: []

# %%
#SALib
salib_rc = wosis.search_records(filtered_corpora, ["salib"], threshold=95.0)
salib_df = wosis.rc_to_df(salib_rc)

salib_df.head()
# Out:
# Empty DataFrame
# Columns: [id, year, title, keywords, abstract, AU, SO, DE, DOI]
# Index: []

# %%
#MADS
mads_rc = wosis.search_records(filtered_corpora, ["mads"], threshold=95.0)
mads_df = wosis.rc_to_df(mads_rc)

mads_df.head()
# Out:
#                     id  year  \
# 0  WOS:000404370900030  2017
# 1  WOS:000334856200002  2014
#
#                                                title  \
# 0  High performance in power generation by pressu...
# 1  Analytical solutions for anomalous dispersion ...
#
#                                             keywords  \
# 0  NATURAL SALINITY GRADIENTS|HOLLOW-FIBER MEMBRA...
# 1  HIGHLY HETEROGENEOUS FORMATIONS|NON-FICKIAN TR...
#
#                                             abstract  \
# 0  pressureretarded osmosis pro is a renewable en...
# 1  groundwater flow and transport often occur in ...
#
#                                                   AU  \
# 0  Sharifan, Hamidreza|Madsen, Henrik T.|Morse, A...
# 1                     O'Malley, D.|Vesselinov, V. V.
#
#                                  SO  \
# 0  DESALINATION AND WATER TREATMENT
# 1       ADVANCES IN WATER RESOURCES
#
#                                                   DE  \
# 0  urmia lake|pressure-retarded osmosis|renewable...
# 1  anomalous dispersion|stochastic transport|anal...
#
#                                DOI
# 0           10.5004/dwt.2017.20555
# 1  10.1016/j.advwatres.2014.02.006

# %% [markdown]
# <hr>
# Finding papers by author: need less specific search criteria
